# %%
import pandas  as pd
import numpy   as np
from functions import variable_impact

# %%
data = pd.read_csv('data/merged_data.csv')

# %%
target_variable = 'HH050'

# %%
# Use the function variable_impact to show the results
#     The function takes 3 parameters:
#     
#         first:  the dataset
#         second: the target variable
#
#         Optional: variables: the variables used to predict, otherwise uses every possible variable.
#
#     Examples:
#          shap_values = variable_impact(data, target_variable)
#          shap_values = variable_impact(data, target_variable, variables = ['vhMATDEP', 'HY010', 'vhRentaAIa', 'HY023', 'HD080'])

shap_values = variable_impact(data, target_variable)
# Out:
# ntree_limit is deprecated, use `iteration_range` or model slicing instead.
